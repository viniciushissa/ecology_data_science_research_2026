# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
df = pd.read_csv("callintrichidae_clean.csv", index_col=0)
df.head()
# Out:
#         genus             species   stateProvince  decimalLatitude  \
# 0  Callithrix   Callithrix aurita       São Paulo       -23.032046
# 1  Callithrix  Callithrix jacchus           Piauí        -8.868018
# 2    Saguinus    Saguinus bicolor        Amazonas        -3.015908
# 3        Mico      Mico melanurus     Mato Grosso       -16.222323
# 4  Callithrix  Callithrix jacchus  Rio de Janeiro       -22.975337
#
#    decimalLongitude coordinateUncertaintyInMeters            eventDate  month  \
# 0        -46.375152                       30217.0           2014-04-20      4
# 1        -42.558185                       Unknown  2012-01-15T09:29:54      1
# 2        -60.044437                       10000.0     2012-05-27T09:10      5
# 3        -56.206741                       Unknown           2009-09-10      9
# 4        -43.230858                       Unknown           2009-08-19      8
#
#    year
# 0  2014
# 1  2012
# 2  2012
# 3  2009
# 4  2009

# %%
df["species"] = df["species"].replace("Unknown", None)
df.dropna(inplace=True)
df.value_counts("species", dropna=False)
# Out:
# species
# Callithrix penicillata        3211
# Callithrix jacchus            2457
# Callithrix geoffroyi           506
# Mico melanurus                 249
# Callithrix aurita              227
# Callithrix kuhlii              180
# Leontocebus weddelli           151
# Saguinus midas                 148
# Saguinus bicolor               136
# Leontopithecus rosalia         114
# Saguinus imperator              98
# Cebuella niveiventris           56
# Saguinus ursula                 56
# Mico argentatus                 55
# Callithrix flaviceps            53
# Leontopithecus chrysopygus      45
# Leontopithecus chrysomelas      40
# Saguinus niger                  39
# Saguinus labiatus               31
# Mico humeralifer                27
# Mico rondoni                    27
# Saguinus mystax                 26
# Mico schneideri                 23
# Leontocebus fuscicollis         21
# Mico emiliae                    20
# Saguinus martinsi               17
# Callimico goeldii               15
# Mico chrysoleucos               12
# Mico leucippe                    8
# Leontopithecus caissara          7
# Cebuella pygmaea                 6
# Mico saterei                     4
# Mico intermedius                 4
# Leontocebus nigricollis          4
# Mico nigriceps                   3
# Mico marcai                      1
# Mico humilis                     1
# Name: count, dtype: int64

# %%
X = df[["decimalLatitude", "decimalLongitude", "year"]]
y = df["species"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=16)

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5460396039603961
#                             precision    recall  f1-score   support
#
#          Callimico goeldii       0.00      0.00      0.00         7
#          Callithrix aurita       0.00      0.00      0.00        51
#       Callithrix flaviceps       0.00      0.00      0.00        17
#       Callithrix geoffroyi       0.00      0.00      0.00       115
#         Callithrix jacchus       0.56      0.56      0.56       624
#          Callithrix kuhlii       0.00      0.00      0.00        42
#     Callithrix penicillata       0.54      0.93      0.69       811
#      Cebuella niveiventris       0.00      0.00      0.00        18
#           Cebuella pygmaea       0.00      0.00      0.00         3
#    Leontocebus fuscicollis       0.00      0.00      0.00         7
#    Leontocebus nigricollis       0.00      0.00      0.00         2
#       Leontocebus weddelli       0.00      0.00      0.00        29
#    Leontopithecus caissara       0.00      0.00      0.00         1
# Leontopithecus chrysomelas       0.00      0.00      0.00        10
# Leontopithecus chrysopygus       0.00      0.00      0.00        10
#     Leontopithecus rosalia       0.00      0.00      0.00        30
#            Mico argentatus       0.00      0.00      0.00        13
#          Mico chrysoleucos       0.00      0.00      0.00         5
#               Mico emiliae       0.00      0.00      0.00         5
#           Mico humeralifer       0.00      0.00      0.00         4
#              Mico leucippe       0.00      0.00      0.00         2
#             Mico melanurus       0.00      0.00      0.00        57
#             Mico nigriceps       0.00      0.00      0.00         1
#               Mico rondoni       0.00      0.00      0.00         5
#               Mico saterei       0.00      0.00      0.00         1
#            Mico schneideri       0.00      0.00      0.00         7
#           Saguinus bicolor       0.00      0.00      0.00        33
#         Saguinus imperator       0.00      0.00      0.00        26
#          Saguinus labiatus       0.00      0.00      0.00         5
#          Saguinus martinsi       0.00      0.00      0.00         4
#             Saguinus midas       0.00      0.00      0.00        44
#            Saguinus mystax       0.00      0.00      0.00         4
#             Saguinus niger       0.00      0.00      0.00         9
#            Saguinus ursula       0.00      0.00      0.00        18
#
#                   accuracy                           0.55      2020
#                  macro avg       0.03      0.04      0.04      2020
#               weighted avg       0.39      0.55      0.45      2020
# /home/vinicius/Documentos/codes/ic_data_science/venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/vinicius/Documentos/codes/ic_data_science/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/vinicius/Documentos/codes/ic_data_science/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/vinicius/Documentos/codes/ic_data_science/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
rfc = RandomForestClassifier(n_estimators=100, class_weight="balanced")
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.842079207920792
#                             precision    recall  f1-score   support
#
#          Callimico goeldii       1.00      0.43      0.60         7
#          Callithrix aurita       0.63      0.61      0.62        51
#       Callithrix flaviceps       1.00      0.76      0.87        17
#       Callithrix geoffroyi       0.90      0.91      0.91       115
#         Callithrix jacchus       0.87      0.84      0.85       624
#          Callithrix kuhlii       0.91      0.93      0.92        42
#     Callithrix penicillata       0.85      0.88      0.87       811
#      Cebuella niveiventris       0.91      0.56      0.69        18
#           Cebuella pygmaea       0.60      1.00      0.75         3
#    Leontocebus fuscicollis       0.00      0.00      0.00         7
#    Leontocebus nigricollis       0.00      0.00      0.00         2
#       Leontocebus weddelli       0.48      0.41      0.44        29
#    Leontopithecus caissara       1.00      1.00      1.00         1
# Leontopithecus chrysomelas       0.78      0.70      0.74        10
# Leontopithecus chrysopygus       1.00      0.90      0.95        10
#     Leontopithecus rosalia       0.85      0.77      0.81        30
#            Mico argentatus       1.00      0.92      0.96        13
#          Mico chrysoleucos       1.00      0.20      0.33         5
#               Mico emiliae       1.00      0.80      0.89         5
#           Mico humeralifer       0.67      1.00      0.80         4
#           Mico intermedius       0.00      0.00      0.00         0
#              Mico leucippe       1.00      0.50      0.67         2
#                Mico marcai       0.00      0.00      0.00         0
#             Mico melanurus       0.98      0.98      0.98        57
#             Mico nigriceps       1.00      1.00      1.00         1
#               Mico rondoni       0.11      0.20      0.14         5
#               Mico saterei       1.00      1.00      1.00         1
#            Mico schneideri       0.88      1.00      0.93         7
#           Saguinus bicolor       0.91      0.97      0.94        33
#         Saguinus imperator       0.45      0.50      0.47        26
#          Saguinus labiatus       0.33      0.60      0.43         5
#          Saguinus martinsi       1.00      0.75      0.86         4
#             Saguinus midas       0.95      0.95      0.95        44
#            Saguinus mystax       0.20      0.50      0.29         4
#             Saguinus niger       0.70      0.78      0.74         9
#            Saguinus ursula       1.00      0.89      0.94        18
#
#                   accuracy                           0.84      2020
#                  macro avg       0.72      0.67      0.68      2020
#               weighted avg       0.85      0.84      0.84      2020
# /home/vinicius/Documentos/codes/ic_data_science/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/vinicius/Documentos/codes/ic_data_science/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/vinicius/Documentos/codes/ic_data_science/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/vinicius/Documentos/codes/ic_data_science/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/vinicius/Documentos/codes/ic_data_science/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/vinicius/Documentos/codes/ic_data_science/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
print("test")
